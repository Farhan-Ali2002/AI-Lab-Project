# %%
### Importing all the required packages and loading csv files
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns
from sklearn import preprocessing
import numpy as np
data = pd.read_csv('Dataset/Dataset.txt')
data_attack = pd.read_csv('Dataset/Attack_types.txt')


# Create new DataFrame with 'Attack category' column
att_cat = data[['attack_category']].copy()

# View the resulting DataFrame
att_cat.head()
# Out:
#   attack_category
# 0          normal
# 1          normal
# 2         neptune
# 3          normal
# 4          normal

# %%
### seperating attack types and categories in attacktype.txt
data_attack[['attack_category', 'attack_type']] = data_attack['attack_category attack_type'].str.split(' ', expand=True)
data_attack.drop('attack_category attack_type',axis = 1, inplace=True)
data_attack.head()
# Out:
#   attack_category attack_type
# 0         apache2         dos
# 1            back         dos
# 2        mailbomb         dos
# 3    processtable         dos
# 4   snmpgetattack         dos

# %%
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#    attack_category  occurance
# 0           normal         20
# 1           normal         15
# 2          neptune         19
# 3           normal         21
# 4           normal         21
#
# [5 rows x 43 columns]

# %%
# my_dict = data_attack.set_index('category')['type'].to_dict()
# my_dict
# merging/joining both datafarmes so that mapping could be done
data = data.merge(data_attack, on='attack_category', how='left')

# %%
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 0               0       0    0  ...                    0.03
# 1               0       0    0  ...                    0.60
# 2               0       0    0  ...                    0.05
# 3               0       0    0  ...                    0.00
# 4               0       0    0  ...                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate  attack_category  occurance  attack_type
# 0                      0.00           normal         20          NaN
# 1                      0.00           normal         15          NaN
# 2                      0.00          neptune         19          dos
# 3                      0.01           normal         21          NaN
# 4                      0.00           normal         21          NaN
#
# [5 rows x 44 columns]

# %%
# for tye in target['attack_category']:
#         target['attack'] = ''

# target.head()

# %%
# for tye in target['attack_category']:
#         pass
# counting value= normal in the dataset
data['attack_category'].value_counts()['normal']
# Out:
# 67343

# %%
# checking null values
nulls =data.isnull().sum()
print(nulls , data.shape)
# Out:
# duration                           0
# protocol_type                      0
# service                            0
# flag                               0
# src_bytes                          0
# dst_bytes                          0
# land                               0
# wrong_fragment                     0
# urgent                             0
# hot                                0
# num_failed_logins                  0
# logged_in                          0
# num_compromised                    0
# root_shell                         0
# su_attempted                       0
# num_root                           0
# num_file_creations                 0
# num_shells                         0
# num_access_files                   0
# num_outbound_cmds                  0
# is_host_login                      0
# is_guest_login                     0
# count                              0
# srv_count                          0
# serror_rate                        0
# srv_serror_rate                    0
# rerror_rate                        0
# srv_rerror_rate                    0
# same_srv_rate                      0
# diff_srv_rate                      0
# srv_diff_host_rate                 0
# dst_host_count                     0
# dst_host_srv_count                 0
# dst_host_same_srv_rate             0
# dst_host_diff_srv_rate             0
# dst_host_same_src_port_rate        0
# dst_host_srv_diff_host_rate        0
# dst_host_serror_rate               0
# dst_host_srv_serror_rate           0
# dst_host_rerror_rate               0
# dst_host_srv_rerror_rate           0
# attack_category                    0
# occurance                          0
# attack_type                    67343
# dtype: int64 (125984, 44)

# %%
# replacing all the null values in attack type with normal because no attack occured
data['attack_type'] = data['attack_type'].replace(np.nan,'normal')

# %%
data['attack_type'].value_counts()['normal']
# Out:
# 67343

# %%
# null values removed 
nulls =data.isnull().sum()
print(nulls , data.shape)
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# diff_srv_rate                  0
# srv_diff_host_rate             0
# dst_host_count                 0
# dst_host_srv_count             0
# dst_host_same_srv_rate         0
# dst_host_diff_srv_rate         0
# dst_host_same_src_port_rate    0
# dst_host_srv_diff_host_rate    0
# dst_host_serror_rate           0
# dst_host_srv_serror_rate       0
# dst_host_rerror_rate           0
# dst_host_srv_rerror_rate       0
# attack_category                0
# occurance                      0
# attack_type                    0
# dtype: int64 (125984, 44)

# %%
data.tail()
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 125979         0           tcp   private   S0          0          0     0
# 125980         8           udp   private   SF        105        145     0
# 125981         0           tcp      smtp   SF       2231        384     0
# 125982         0           tcp    klogin   S0          0          0     0
# 125983         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 125979               0       0    0  ...                    0.06
# 125980               0       0    0  ...                    0.01
# 125981               0       0    0  ...                    0.06
# 125982               0       0    0  ...                    0.05
# 125983               0       0    0  ...                    0.03
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 125979                         0.00                          0.0
# 125980                         0.01                          0.0
# 125981                         0.00                          0.0
# 125982                         0.00                          0.0
# 125983                         0.30                          0.0
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 125979                  1.00                       1.0                  0.00
# 125980                  0.00                       0.0                  0.00
# 125981                  0.72                       0.0                  0.01
# 125982                  1.00                       1.0                  0.00
# 125983                  0.00                       0.0                  0.00
#
#         dst_host_srv_rerror_rate  attack_category  occurance  attack_type
# 125979                       0.0          neptune         20          dos
# 125980                       0.0           normal         21       normal
# 125981                       0.0           normal         18       normal
# 125982                       0.0          neptune         20          dos
# 125983                       0.0           normal         21       normal
#
# [5 rows x 44 columns]

# %%
# dropping attack category column because it is no longer needed
data.drop('attack_category' ,axis = 1, inplace=True)
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#    occurance  attack_type
# 0         20       normal
# 1         15       normal
# 2         19          dos
# 3         21       normal
# 4         21       normal
#
# [5 rows x 43 columns]

# %%
for i in data:
    if data[i].dtype == 'object':
        print(f" {i} = {data[i].unique()}")
# Out:
#  protocol_type = ['tcp' 'udp' 'icmp']
#  service = ['ftp_data' 'other' 'private' 'http' 'remote_job' 'name' 'netbios_ns'
#  'eco_i' 'mtp' 'telnet' 'finger' 'domain_u' 'supdup' 'uucp_path' 'Z39_50'
#  'smtp' 'csnet_ns' 'uucp' 'netbios_dgm' 'urp_i' 'auth' 'domain' 'ftp'
#  'bgp' 'ldap' 'ecr_i' 'gopher' 'vmnet' 'systat' 'http_443' 'efs' 'whois'
#  'imap4' 'iso_tsap' 'echo' 'klogin' 'link' 'sunrpc' 'login' 'kshell'
#  'sql_net' 'time' 'hostnames' 'exec' 'ntp_u' 'discard' 'nntp' 'courier'
#  'ctf' 'ssh' 'daytime' 'shell' 'netstat' 'pop_3' 'nnsp' 'IRC' 'pop_2'
#  'printer' 'tim_i' 'pm_dump' 'red_i' 'netbios_ssn' 'rje' 'X11' 'urh_i'
#  'http_8001' 'aol' 'http_2784' 'tftp_u' 'harvest']
#  flag = ['SF' 'S0' 'REJ' 'RSTR' 'SH' 'RSTO' 'S1' 'RSTOS0' 'S3' 'S2' 'OTH']
#  attack_type = ['normal' 'dos' 'r2l' 'probe' 'u2r']

# %%
data.shape
# Out:
# (125984, 43)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125984 entries, 0 to 125983
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125984 non-null  int64
#  1   protocol_type                125984 non-null  object
#  2   service                      125984 non-null  object
#  3   flag                         125984 non-null  object
#  4   src_bytes                    125984 non-null  int64
#  5   dst_bytes                    125984 non-null  int64
#  6   land                         125984 non-null  int64
#  7   wrong_fragment               125984 non-null  int64
#  8   urgent                       125984 non-null  int64
#  9   hot                          125984 non-null  int64
#  10  num_failed_logins            125984 non-null  int64
#  11  logged_in                    125984 non-null  int64
#  12  num_compromised              125984 non-null  int64
#  13  root_shell                   125984 non-null  int64
#  14  su_attempted                 125984 non-null  int64
#  15  num_root                     125984 non-null  int64
#  16  num_file_creations           125984 non-null  int64
#  17  num_shells                   125984 non-null  int64
#  18  num_access_files             125984 non-null  int64
#  19  num_outbound_cmds            125984 non-null  int64
#  20  is_host_login                125984 non-null  int64
#  21  is_guest_login               125984 non-null  int64
#  22  count                        125984 non-null  int64
#  23  srv_count                    125984 non-null  int64
#  24  serror_rate                  125984 non-null  float64
#  25  srv_serror_rate              125984 non-null  float64
#  26  rerror_rate                  125984 non-null  float64
#  27  srv_rerror_rate              125984 non-null  float64
#  28  same_srv_rate                125984 non-null  float64
#  29  diff_srv_rate                125984 non-null  float64
#  30  srv_diff_host_rate           125984 non-null  float64
#  31  dst_host_count               125984 non-null  int64
#  32  dst_host_srv_count           125984 non-null  int64
#  33  dst_host_same_srv_rate       125984 non-null  float64
#  34  dst_host_diff_srv_rate       125984 non-null  float64
#  35  dst_host_same_src_port_rate  125984 non-null  float64
#  36  dst_host_srv_diff_host_rate  125984 non-null  float64
#  37  dst_host_serror_rate         125984 non-null  float64
#  38  dst_host_srv_serror_rate     125984 non-null  float64
#  39  dst_host_rerror_rate         125984 non-null  float64
#  40  dst_host_srv_rerror_rate     125984 non-null  float64
#  41  occurance                    125984 non-null  int64
#  42  attack_type                  125984 non-null  object
# dtypes: float64(15), int64(24), object(4)
# memory usage: 42.3+ MB

# %%
data.describe()
# Out:
#             duration     src_bytes     dst_bytes           land  \
# count  125984.000000  1.259840e+05  1.259840e+05  125984.000000
# mean      287.120150  4.556280e+04  1.978262e+04       0.000198
# std      2604.402926  5.870075e+06  4.021094e+06       0.014085
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.000000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.000000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.000000  2.760000e+02  5.160000e+02       0.000000
# max     42908.000000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125984.000000  125984.000000  125984.000000      125984.000000
# mean         0.022685       0.000111       0.204423           0.001222
# std          0.253519       0.014365       2.149887           0.045237
# min          0.000000       0.000000       0.000000           0.000000
# 25%          0.000000       0.000000       0.000000           0.000000
# 50%          0.000000       0.000000       0.000000           0.000000
# 75%          0.000000       0.000000       0.000000           0.000000
# max          3.000000       3.000000      77.000000           5.000000
#
#            logged_in  num_compromised  ...  dst_host_srv_count  \
# count  125984.000000    125984.000000  ...       125984.000000
# mean        0.395709         0.279353  ...          115.643391
# std         0.489004        23.941038  ...          110.702693
# min         0.000000         0.000000  ...            0.000000
# 25%         0.000000         0.000000  ...           10.000000
# 50%         0.000000         0.000000  ...           63.000000
# 75%         1.000000         0.000000  ...          255.000000
# max         1.000000      7479.000000  ...          255.000000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count           125984.000000           125984.000000
# mean                 0.521276                0.082944
# std                  0.448952                0.188915
# min                  0.000000                0.000000
# 25%                  0.050000                0.000000
# 50%                  0.510000                0.020000
# 75%                  1.000000                0.070000
# max                  1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                125984.000000                125984.000000
# mean                      0.148424                     0.032540
# std                       0.309041                     0.112559
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.060000                     0.020000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count         125984.000000             125984.000000         125984.000000
# mean               0.284478                  0.278511              0.118822
# std                0.444780                  0.445665              0.306546
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                1.000000                  1.000000              0.000000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate      occurance
# count             125984.000000  125984.000000
# mean                   0.120229      19.503707
# std                    0.319447       2.292028
# min                    0.000000       0.000000
# 25%                    0.000000      18.000000
# 50%                    0.000000      20.000000
# 75%                    0.000000      21.000000
# max                    1.000000      21.000000
#
# [8 rows x 39 columns]

# %%
sns.histplot(data['duration'])
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %%
sns.histplot(data['urgent'])
# Out:
# <AxesSubplot:xlabel='urgent', ylabel='Count'>

# %%
duplicate_rows_df = data[data.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (20, 43)

# %%
data.count()
# Out:
# duration                       125984
# protocol_type                  125984
# service                        125984
# flag                           125984
# src_bytes                      125984
# dst_bytes                      125984
# land                           125984
# wrong_fragment                 125984
# urgent                         125984
# hot                            125984
# num_failed_logins              125984
# logged_in                      125984
# num_compromised                125984
# root_shell                     125984
# su_attempted                   125984
# num_root                       125984
# num_file_creations             125984
# num_shells                     125984
# num_access_files               125984
# num_outbound_cmds              125984
# is_host_login                  125984
# is_guest_login                 125984
# count                          125984
# srv_count                      125984
# serror_rate                    125984
# srv_serror_rate                125984
# rerror_rate                    125984
# srv_rerror_rate                125984
# same_srv_rate                  125984
# diff_srv_rate                  125984
# srv_diff_host_rate             125984
# dst_host_count                 125984
# dst_host_srv_count             125984
# dst_host_same_srv_rate         125984
# dst_host_diff_srv_rate         125984
# dst_host_same_src_port_rate    125984
# dst_host_srv_diff_host_rate    125984
# dst_host_serror_rate           125984
# dst_host_srv_serror_rate       125984
# dst_host_rerror_rate           125984
# dst_host_srv_rerror_rate       125984
# occurance                      125984
# attack_type                    125984
# dtype: int64

# %%
data.shape
# Out:
# (125984, 43)

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (125964, 43)

# %%
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#    occurance  attack_type
# 0         20       normal
# 1         15       normal
# 2         19          dos
# 3         21       normal
# 4         21       normal
#
# [5 rows x 43 columns]

# %%
for col in data.columns:
    if data[col].dtype != object:
        mp.hist(data[col], bins=5)
        mp.title(col)
        mp.show()

# %%
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125979         0           tcp   private   S0          0          0     0
# 125980         8           udp   private   SF        105        145     0
# 125981         0           tcp      smtp   SF       2231        384     0
# 125982         0           tcp    klogin   S0          0          0     0
# 125983         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 125979               0       0    0  ...                    0.10
# 125980               0       0    0  ...                    0.96
# 125981               0       0    0  ...                    0.12
# 125982               0       0    0  ...                    0.03
# 125983               0       0    0  ...                    0.30
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 125979                    0.06                         0.00
# 125980                    0.01                         0.01
# 125981                    0.06                         0.00
# 125982                    0.05                         0.00
# 125983                    0.03                         0.30
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 125979                         0.00                  1.00
# 125980                         0.00                  0.00
# 125981                         0.00                  0.72
# 125982                         0.00                  1.00
# 125983                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 125979                      1.00                  0.00
# 125980                      0.00                  0.00
# 125981                      0.00                  0.01
# 125982                      1.00                  0.00
# 125983                      0.00                  0.00
#
#         dst_host_srv_rerror_rate  occurance  attack_type
# 0                           0.00         20       normal
# 1                           0.00         15       normal
# 2                           0.00         19          dos
# 3                           0.01         21       normal
# 4                           0.00         21       normal
# ...                          ...        ...          ...
# 125979                      0.00         20          dos
# 125980                      0.00         21       normal
# 125981                      0.00         18       normal
# 125982                      0.00         20          dos
# 125983                      0.00         21       normal
#
# [125964 rows x 43 columns]

# %%
from sklearn.preprocessing import LabelEncoder
 
# Creating a instance of label Encoder.
le = LabelEncoder()
categories = ['service','protocol_type','flag']
for category in categories:
# Using .fit_transform function to fit label
# encoder and return encoded label
    label = le.fit_transform(data[category])
    data.drop(category,axis=1)
    data[category] = label
 
 #printing label
    print(label)
data.head()
# Out:
# [20 44 49 ... 54 30 20]
# [1 2 1 ... 1 1 1]
# [9 9 5 ... 9 5 9]
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       20     9        491          0     0
# 1         0              2       44     9        146          0     0
# 2         0              1       49     5          0          0     0
# 3         0              1       24     9        232       8153     0
# 4         0              1       24     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#    occurance  attack_type
# 0         20       normal
# 1         15       normal
# 2         19          dos
# 3         21       normal
# 4         21       normal
#
# [5 rows x 43 columns]

# %%
from sklearn.model_selection import train_test_split
x = data.drop('attack_type',axis=1)
y = data['attack_type']

X_train, X_test, y_train, y_test =train_test_split(x,y,test_size=0.3,random_state =0)
X_train.shape, X_test.shape
# Out:
# ((88174, 42), (37790, 42))

# %%
corr
# Out:
#                              duration  src_bytes  dst_bytes      land  \
# duration                     1.000000   0.072642   0.051773 -0.001710
# src_bytes                    0.072642   1.000000   0.000836 -0.000124
# dst_bytes                    0.051773   0.000836   1.000000 -0.000088
# land                        -0.001710  -0.000124  -0.000088  1.000000
# wrong_fragment              -0.009814  -0.000710  -0.000503 -0.001367
# urgent                       0.004711  -0.000069   0.000988 -0.000135
# hot                         -0.001034   0.000239  -0.000182 -0.001474
# num_failed_logins            0.011310  -0.000220   0.002326 -0.000426
# logged_in                   -0.064936  -0.003859  -0.001269 -0.012506
# num_compromised              0.089774  -0.000153   0.002242 -0.000311
# root_shell                   0.049023  -0.000288   0.003057 -0.000579
# su_attempted                 0.084915  -0.000194   0.003397 -0.000380
# num_root                     0.089197  -0.000158   0.002165 -0.000312
# num_file_creations           0.098763  -0.000191   0.000499 -0.000409
# num_shells                  -0.001705  -0.000145  -0.000091 -0.000296
# num_access_files             0.071288  -0.000327   0.001394 -0.000646
# num_outbound_cmds                 NaN        NaN        NaN       NaN
# is_host_login                     NaN        NaN        NaN       NaN
# is_guest_login              -0.000193  -0.000774  -0.000380 -0.001513
# count                       -0.079437  -0.005240  -0.004029 -0.011188
# srv_count                   -0.039554  -0.002884  -0.001901 -0.005501
# serror_rate                 -0.070224  -0.003006  -0.003399  0.023647
# srv_serror_rate             -0.069805  -0.003280  -0.003385  0.024784
# rerror_rate                  0.200149   0.014495   0.008406 -0.004247
# srv_rerror_rate              0.198934   0.014759   0.008311 -0.005785
# same_srv_rate                0.075442   0.003626   0.004368  0.010793
# diff_srv_rate               -0.015302  -0.000119  -0.001954 -0.001322
# srv_diff_host_rate          -0.040618  -0.002686  -0.001638  0.039695
# dst_host_count               0.049517  -0.005674   0.000921 -0.027908
# dst_host_srv_count          -0.110388  -0.007103  -0.003247 -0.015502
# dst_host_same_srv_rate      -0.116404  -0.006976  -0.002710  0.011973
# dst_host_diff_srv_rate       0.252663   0.000958   0.006683 -0.004607
# dst_host_same_src_port_rate  0.227614   0.000296   0.009999  0.035925
# dst_host_srv_diff_host_rate -0.026441  -0.001789  -0.001201  0.069708
# dst_host_serror_rate        -0.065386  -0.004625  -0.003226  0.021159
# dst_host_srv_serror_rate    -0.064957  -0.003227  -0.003118  0.013375
# dst_host_rerror_rate         0.170600  -0.001403   0.008919 -0.005683
# dst_host_srv_rerror_rate     0.197027   0.012807   0.008478 -0.005818
# occurance                   -0.153414  -0.023480  -0.016382 -0.042426
#
#                              wrong_fragment    urgent       hot  \
# duration                          -0.009814  0.004711 -0.001034
# src_bytes                         -0.000710 -0.000069  0.000239
# dst_bytes                         -0.000503  0.000988 -0.000182
# land                              -0.001367 -0.000135 -0.001474
# wrong_fragment                     1.000000 -0.000776 -0.008458
# urgent                            -0.000776  1.000000  0.000423
# hot                               -0.008458  0.000423  1.000000
# num_failed_logins                 -0.002445  0.109953  0.002894
# logged_in                         -0.071772  0.008053  0.116649
# num_compromised                   -0.001782  0.091278 -0.000426
# root_shell                        -0.003324  0.089541  0.015090
# su_attempted                      -0.002180  0.119082 -0.000824
# num_root                          -0.001791  0.082142 -0.001307
# num_file_creations                -0.002345  0.029867  0.022024
# num_shells                        -0.001697 -0.000168  0.002304
# num_access_files                  -0.003706  0.012920 -0.003158
# num_outbound_cmds                       NaN       NaN       NaN
# is_host_login                           NaN       NaN       NaN
# is_guest_login                    -0.008682 -0.000858  0.861466
# count                             -0.019169 -0.006354 -0.068957
# srv_count                          0.026137 -0.003213 -0.034619
# serror_rate                       -0.042295 -0.005576 -0.059631
# srv_serror_rate                   -0.055945 -0.005530 -0.059196
# rerror_rate                       -0.032788 -0.003280 -0.032475
# srv_rerror_rate                   -0.033200 -0.003282 -0.031533
# same_srv_rate                      0.053742  0.006758  0.069729
# diff_srv_rate                     -0.026443 -0.003059 -0.016114
# srv_diff_host_rate                -0.026037 -0.003271 -0.027009
# dst_host_count                     0.039889 -0.007246 -0.013770
# dst_host_srv_count                -0.043840 -0.008926 -0.052766
# dst_host_same_srv_rate            -0.047100 -0.005442 -0.036643
# dst_host_diff_srv_rate             0.061439  0.005045 -0.010634
# dst_host_same_src_port_rate        0.038211  0.002550 -0.034471
# dst_host_srv_diff_host_rate       -0.016257  0.006481 -0.024237
# dst_host_serror_rate              -0.051298 -0.005353 -0.058729
# dst_host_srv_serror_rate          -0.055297 -0.005466 -0.058559
# dst_host_rerror_rate               0.028275 -0.003401 -0.030130
# dst_host_srv_rerror_rate          -0.033388 -0.003301 -0.031765
# occurance                         -0.154006 -0.015125 -0.159529
#
#                              num_failed_logins  logged_in  num_compromised  \
# duration                              0.011310  -0.064936         0.089774
# src_bytes                            -0.000220  -0.003859        -0.000153
# dst_bytes                             0.002326  -0.001269         0.002242
# land                                 -0.000426  -0.012506        -0.000311
# wrong_fragment                       -0.002445  -0.071772        -0.001782
# urgent                                0.109953   0.008053         0.091278
# hot                                   0.002894   0.116649        -0.000426
# num_failed_logins                     1.000000  -0.005293         0.053553
# logged_in                            -0.005293   1.000000         0.024832
# num_compromised                       0.053553   0.024832         1.000000
# root_shell                            0.036098   0.046315         0.475912
# su_attempted                          0.081477   0.030368         0.790425
# num_root                              0.046907   0.024959         0.998014
# num_file_creations                    0.026121   0.032572         0.014975
# num_shells                           -0.000529   0.023648         0.000628
# num_access_files                      0.001133   0.051631         0.702421
# num_outbound_cmds                          NaN        NaN              NaN
# is_host_login                              NaN        NaN              NaN
# is_guest_login                        0.006851   0.119770        -0.001972
# count                                -0.019953  -0.540394        -0.014520
# srv_count                            -0.010063  -0.198758        -0.007353
# serror_rate                          -0.015238  -0.493173        -0.011177
# srv_serror_rate                      -0.016134  -0.491045        -0.011181
# rerror_rate                           0.019671  -0.288424        -0.005566
# srv_rerror_rate                       0.019357  -0.284242        -0.005464
# same_srv_rate                         0.019499   0.602449         0.015411
# diff_srv_rate                        -0.003028  -0.221579        -0.006969
# srv_diff_host_rate                   -0.010309   0.127597        -0.007183
# dst_host_count                       -0.025287  -0.399560        -0.015405
# dst_host_srv_count                   -0.023480   0.626119        -0.017639
# dst_host_same_srv_rate               -0.002060   0.606527        -0.009996
# dst_host_diff_srv_rate               -0.001935  -0.257306         0.005129
# dst_host_same_src_port_rate          -0.004750  -0.161735        -0.001551
# dst_host_srv_diff_host_rate           0.006676  -0.054534         0.016145
# dst_host_serror_rate                 -0.011466  -0.492484        -0.005765
# dst_host_srv_serror_rate             -0.012467  -0.493989        -0.008373
# dst_host_rerror_rate                  0.017413  -0.277546        -0.006074
# dst_host_srv_rerror_rate              0.015472  -0.273786        -0.005328
# occurance                            -0.075327   0.267983        -0.011256
#
#                              ...  dst_host_srv_count  dst_host_same_srv_rate  \
# duration                     ...           -0.110388               -0.116404
# src_bytes                    ...           -0.007103               -0.006976
# dst_bytes                    ...           -0.003247               -0.002710
# land                         ...           -0.015502                0.011973
# wrong_fragment               ...           -0.043840               -0.047100
# urgent                       ...           -0.008926               -0.005442
# hot                          ...           -0.052766               -0.036643
# num_failed_logins            ...           -0.023480               -0.002060
# logged_in                    ...            0.626119                0.606527
# num_compromised              ...           -0.017639               -0.009996
# root_shell                   ...           -0.006423                0.008396
# su_attempted                 ...           -0.021853               -0.016041
# num_root                     ...           -0.018133               -0.011188
# num_file_creations           ...           -0.019701               -0.017442
# num_shells                   ...           -0.012328               -0.006692
# num_access_files             ...            0.002510                0.007372
# num_outbound_cmds            ...                 NaN                     NaN
# is_host_login                ...                 NaN                     NaN
# is_guest_login               ...           -0.067143               -0.055236
# count                        ...           -0.398322               -0.477027
# srv_count                    ...            0.200125                0.178151
# serror_rate                  ...           -0.557845               -0.622870
# srv_serror_rate              ...           -0.554966               -0.618983
# rerror_rate                  ...           -0.250257               -0.256848
# srv_rerror_rate              ...           -0.248847               -0.254972
# same_srv_rate                ...            0.706268                0.789914
# diff_srv_rate                ...           -0.301151               -0.330629
# srv_diff_host_rate           ...            0.153543                0.292737
# dst_host_count               ...           -0.304436               -0.519786
# dst_host_srv_count           ...            1.000000                0.896772
# dst_host_same_srv_rate       ...            0.896772                1.000000
# dst_host_diff_srv_rate       ...           -0.390580               -0.419781
# dst_host_same_src_port_rate  ...           -0.067079                0.135948
# dst_host_srv_diff_host_rate  ...           -0.005266                0.199432
# dst_host_serror_rate         ...           -0.572610               -0.639084
# dst_host_srv_serror_rate     ...           -0.567564               -0.631978
# dst_host_rerror_rate         ...           -0.249722               -0.257046
# dst_host_srv_rerror_rate     ...           -0.251616               -0.257475
# occurance                    ...            0.273911                0.127529
#
#                              dst_host_diff_srv_rate  \
# duration                                   0.252663
# src_bytes                                  0.000958
# dst_bytes                                  0.006683
# land                                      -0.004607
# wrong_fragment                             0.061439
# urgent                                     0.005045
# hot                                       -0.010634
# num_failed_logins                         -0.001935
# logged_in                                 -0.257306
# num_compromised                            0.005129
# root_shell                                -0.006865
# su_attempted                               0.002555
# num_root                                   0.005641
# num_file_creations                         0.006056
# num_shells                                -0.002632
# num_access_files                           0.001007
# num_outbound_cmds                               NaN
# is_host_login                                   NaN
# is_guest_login                            -0.006428
# count                                      0.169100
# srv_count                                 -0.105800
# serror_rate                               -0.018918
# srv_serror_rate                           -0.029890
# rerror_rate                                0.372321
# srv_rerror_rate                            0.377001
# same_srv_rate                             -0.167998
# diff_srv_rate                              0.498161
# srv_diff_host_rate                        -0.119635
# dst_host_count                             0.146640
# dst_host_srv_count                        -0.390580
# dst_host_same_srv_rate                    -0.419781
# dst_host_diff_srv_rate                     1.000000
# dst_host_same_src_port_rate                0.231623
# dst_host_srv_diff_host_rate                0.015594
# dst_host_serror_rate                      -0.018351
# dst_host_srv_serror_rate                  -0.027038
# dst_host_rerror_rate                       0.409163
# dst_host_srv_rerror_rate                   0.382117
# occurance                                 -0.176671
#
#                              dst_host_same_src_port_rate  \
# duration                                        0.227614
# src_bytes                                       0.000296
# dst_bytes                                       0.009999
# land                                            0.035925
# wrong_fragment                                  0.038211
# urgent                                          0.002550
# hot                                            -0.034471
# num_failed_logins                              -0.004750
# logged_in                                      -0.161735
# num_compromised                                -0.001551
# root_shell                                      0.003254
# su_attempted                                   -0.005484
# num_root                                       -0.000592
# num_file_creations                             -0.006742
# num_shells                                      0.012638
# num_access_files                               -0.011800
# num_outbound_cmds                                    NaN
# is_host_login                                        NaN
# is_guest_login                                 -0.035717
# count                                          -0.140418
# srv_count                                       0.158164
# serror_rate                                    -0.276484
# srv_serror_rate                                -0.275507
# rerror_rate                                     0.031155
# srv_rerror_rate                                 0.028255
# same_srv_rate                                   0.281113
# diff_srv_rate                                  -0.013511
# srv_diff_host_rate                              0.250390
# dst_host_count                                 -0.313074
# dst_host_srv_count                             -0.067079
# dst_host_same_srv_rate                          0.135948
# dst_host_diff_srv_rate                          0.231623
# dst_host_same_src_port_rate                     1.000000
# dst_host_srv_diff_host_rate                     0.405333
# dst_host_serror_rate                           -0.279079
# dst_host_srv_serror_rate                       -0.277076
# dst_host_rerror_rate                            0.037315
# dst_host_srv_rerror_rate                        0.026029
# occurance                                      -0.339565
#
#                              dst_host_srv_diff_host_rate  \
# duration                                       -0.026441
# src_bytes                                      -0.001789
# dst_bytes                                      -0.001201
# land                                            0.069708
# wrong_fragment                                 -0.016257
# urgent                                          0.006481
# hot                                            -0.024237
# num_failed_logins                               0.006676
# logged_in                                      -0.054534
# num_compromised                                 0.016145
# root_shell                                      0.016131
# su_attempted                                    0.010709
# num_root                                        0.015648
# num_file_creations                              0.001042
# num_shells                                     -0.001706
# num_access_files                                0.002094
# num_outbound_cmds                                    NaN
# is_host_login                                        NaN
# is_guest_login                                 -0.023829
# count                                          -0.205544
# srv_count                                      -0.059362
# serror_rate                                    -0.173188
# srv_serror_rate                                -0.171110
# rerror_rate                                     0.033648
# srv_rerror_rate                                 0.030503
# same_srv_rate                                   0.216535
# diff_srv_rate                                  -0.084334
# srv_diff_host_rate                              0.377723
# dst_host_count                                 -0.456395
# dst_host_srv_count                             -0.005266
# dst_host_same_srv_rate                          0.199432
# dst_host_diff_srv_rate                          0.015594
# dst_host_same_src_port_rate                     0.405333
# dst_host_srv_diff_host_rate                     1.000000
# dst_host_serror_rate                           -0.174498
# dst_host_srv_serror_rate                       -0.173266
# dst_host_rerror_rate                            0.039096
# dst_host_srv_rerror_rate                        0.039377
# occurance                                      -0.230590
#
#                              dst_host_serror_rate  dst_host_srv_serror_rate  \
# duration                                -0.065386                 -0.064957
# src_bytes                               -0.004625                 -0.003227
# dst_bytes                               -0.003226                 -0.003118
# land                                     0.021159                  0.013375
# wrong_fragment                          -0.051298                 -0.055297
# urgent                                  -0.005353                 -0.005466
# hot                                     -0.058729                 -0.058559
# num_failed_logins                       -0.011466                 -0.012467
# logged_in                               -0.492484                 -0.493989
# num_compromised                         -0.005765                 -0.008373
# root_shell                              -0.018549                 -0.017572
# su_attempted                            -0.006707                 -0.005985
# num_root                                -0.006252                 -0.008620
# num_file_creations                       0.002165                 -0.000384
# num_shells                              -0.011316                 -0.008996
# num_access_files                        -0.017546                 -0.020440
# num_outbound_cmds                             NaN                       NaN
# is_host_login                                 NaN                       NaN
# is_guest_login                          -0.060933                 -0.060705
# count                                    0.461033                  0.462527
# srv_count                               -0.144348                 -0.143863
# serror_rate                              0.979733                  0.981389
# srv_serror_rate                          0.978035                  0.986242
# rerror_rate                             -0.226090                 -0.225222
# srv_rerror_rate                         -0.226479                 -0.231018
# same_srv_rate                           -0.760480                 -0.765140
# diff_srv_rate                            0.048496                  0.044822
# srv_diff_host_rate                      -0.226567                 -0.226357
# dst_host_count                           0.411131                  0.408177
# dst_host_srv_count                      -0.572610                 -0.567564
# dst_host_same_srv_rate                  -0.639084                 -0.631978
# dst_host_diff_srv_rate                  -0.018351                 -0.027038
# dst_host_same_src_port_rate             -0.279079                 -0.277076
# dst_host_srv_diff_host_rate             -0.174498                 -0.173266
# dst_host_serror_rate                     1.000000                  0.985286
# dst_host_srv_serror_rate                 0.985286                  1.000000
# dst_host_rerror_rate                    -0.235636                 -0.234923
# dst_host_srv_rerror_rate                -0.227997                 -0.233157
# occurance                                0.006090                  0.017854
#
#                              dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# duration                                 0.170600                  0.197027
# src_bytes                               -0.001403                  0.012807
# dst_bytes                                0.008919                  0.008478
# land                                    -0.005683                 -0.005818
# wrong_fragment                           0.028275                 -0.033388
# urgent                                  -0.003401                 -0.003301
# hot                                     -0.030130                 -0.031765
# num_failed_logins                        0.017413                  0.015472
# logged_in                               -0.277546                 -0.273786
# num_compromised                         -0.006074                 -0.005328
# root_shell                              -0.010406                 -0.010049
# su_attempted                            -0.005697                 -0.005727
# num_root                                -0.006067                 -0.005578
# num_file_creations                      -0.005531                 -0.004185
# num_shells                              -0.003906                 -0.006915
# num_access_files                        -0.014044                 -0.013629
# num_outbound_cmds                             NaN                       NaN
# is_host_login                                 NaN                       NaN
# is_guest_login                          -0.030743                 -0.033268
# count                                    0.179274                  0.168646
# srv_count                               -0.100236                 -0.112515
# serror_rate                             -0.232164                 -0.226950
# srv_serror_rate                         -0.235572                 -0.233429
# rerror_rate                              0.926601                  0.965340
# srv_rerror_rate                          0.917759                  0.970466
# same_srv_rate                           -0.215481                 -0.215549
# diff_srv_rate                            0.226746                  0.280553
# srv_diff_host_rate                      -0.076200                 -0.080472
# dst_host_count                           0.071271                  0.066162
# dst_host_srv_count                      -0.249722                 -0.251616
# dst_host_same_srv_rate                  -0.257046                 -0.257475
# dst_host_diff_srv_rate                   0.409163                  0.382117
# dst_host_same_src_port_rate              0.037315                  0.026029
# dst_host_srv_diff_host_rate              0.039096                  0.039377
# dst_host_serror_rate                    -0.235636                 -0.227997
# dst_host_srv_serror_rate                -0.234923                 -0.233157
# dst_host_rerror_rate                     1.000000                  0.924863
# dst_host_srv_rerror_rate                 0.924863                  1.000000
# occurance                               -0.098934                 -0.089239
#
#                              occurance
# duration                     -0.153414
# src_bytes                    -0.023480
# dst_bytes                    -0.016382
# land                         -0.042426
# wrong_fragment               -0.154006
# urgent                       -0.015125
# hot                          -0.159529
# num_failed_logins            -0.075327
# logged_in                     0.267983
# num_compromised              -0.011256
# root_shell                   -0.062948
# su_attempted                 -0.021288
# num_root                     -0.008133
# num_file_creations           -0.037439
# num_shells                   -0.029464
# num_access_files             -0.001868
# num_outbound_cmds                  NaN
# is_host_login                      NaN
# is_guest_login               -0.112777
# count                        -0.029937
# srv_count                    -0.113866
# serror_rate                   0.010415
# srv_serror_rate               0.014336
# rerror_rate                  -0.101884
# srv_rerror_rate              -0.102157
# same_srv_rate                -0.016676
# diff_srv_rate                -0.056114
# srv_diff_host_rate           -0.045460
# dst_host_count                0.023206
# dst_host_srv_count            0.273911
# dst_host_same_srv_rate        0.127529
# dst_host_diff_srv_rate       -0.176671
# dst_host_same_src_port_rate  -0.339565
# dst_host_srv_diff_host_rate  -0.230590
# dst_host_serror_rate          0.006090
# dst_host_srv_serror_rate      0.017854
# dst_host_rerror_rate         -0.098934
# dst_host_srv_rerror_rate     -0.089239
# occurance                     1.000000
#
# [39 rows x 39 columns]

# %%
mp.figure(figsize=(80,40))
corr = X_train.corr()
sns.heatmap(corr, annot= True,cmap = mp.cm.CMRmap_r,square=True, linewidth =.5)
mp.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.85)
len(set(corr_features))
# Out:
# 9

# %%
corr_features
# Out:
# {'dst_host_rerror_rate',
#  'dst_host_same_srv_rate',
#  'dst_host_serror_rate',
#  'dst_host_srv_rerror_rate',
#  'dst_host_srv_serror_rate',
#  'is_guest_login',
#  'num_root',
#  'srv_rerror_rate',
#  'srv_serror_rate'}
